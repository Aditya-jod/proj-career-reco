# %% [markdown]
# # University data reading

# %%
import pandas as pd 
import numpy as np

# %%
in_cl_path = r"D:\Data Science advance projects\Career Path Recommender\Dataset\data of all colleges in india\College.csv"
wd_cl_path = r"D:\Data Science advance projects\Career Path Recommender\Dataset\world universities data\list_of_universities.csv"

# %%
df_india = pd.read_csv(in_cl_path)
df_world = pd.read_csv(wd_cl_path)

df_india.head(10)
# Out:
#                          State                  District  \
# 0  Andaman and Nicobar Islands                  Nicobars
# 1  Andaman and Nicobar Islands                  Nicobars
# 2  Andaman and Nicobar Islands                  Nicobars
# 3  Andaman and Nicobar Islands                  Nicobars
# 4  Andaman and Nicobar Islands  North and Middle Andaman
# 5  Andaman and Nicobar Islands            South Andamans
# 6  Andaman and Nicobar Islands            South Andamans
# 7  Andaman and Nicobar Islands            South Andamans
# 8  Andaman and Nicobar Islands            South Andamans
# 9               Andhra Pradesh                 Anantapur
#
#             University Type  \
# 0       Central University
# 1       Central University
# 2       Central University
# 3       Central University
# 4       Central University
# 5       Central University
# 6       Central University
# 7       Central University
# 8       Central University
# 9  State Public University
#
# ...

# %%
df_world.head(10)
# Out:
#    id                                               name      country  \
# 0   0                            St. George's University      Grenada
# 1   1  Schiller International University, American Co...  Switzerland
# 2   2               Business and Hotel Management School  Switzerland
# 3   3                     Business School Lausanne (BSL)  Switzerland
# 4   4                     Cubidor University Switzerland  Switzerland
# 5   5  DCT International Hotel & Business Management ...  Switzerland
# 6   6   European Graduate School, Media & Communications  Switzerland
# 7   7                        Lausanne Hotel School (EHL)  Switzerland
# 8   8                                European University  Switzerland
# 9   9                       Franklin College Switzerland  Switzerland
#
#   country_code                         web_pages
# 0           GD               http://www.sgu.edu/
# 1           CH  http://www.american-college.com/
# ...

# %%
df_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47590 entries, 0 to 47589
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               47590 non-null  object
#  1   District                            47589 non-null  object
#  2   University Type                     47589 non-null  object
#  3   University Name                     47589 non-null  object
#  4   College Name                        47589 non-null  object
#  5   College Type                        47589 non-null  object
#  6   Address                             44531 non-null  object
#  7   Website                             36097 non-null  object
#  8   Management                          44531 non-null  object
#  9   Year of Establishment
#               44297 non-null  float64
#  10  Specialised in                      44313 non-null  object
# ...

# %%
df_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9255 entries, 0 to 9254
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            9255 non-null   int64
#  1   name          9255 non-null   object
#  2   country       9255 non-null   object
#  3   country_code  9250 non-null   object
#  4   web_pages     9255 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 361.7+ KB
